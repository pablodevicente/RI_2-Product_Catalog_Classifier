# %% [markdown]
# #### Test it on google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir images
# !cp /content/drive/MyDrive/"Colab Notebooks"/images/* /content/images

# %%
# !rm -r sample_data
# !mkdir logs
# !pip3 install PyMuPDF >> logs/log_fitz.txt
# !pip install frontend >> logs/log_frontend.txt
# !pip install pdfplumber >> logs/log_pdf.txt
# !pip install logger >> logs/log_logger.txt
# !pip install bitsandbytes >> logs/log_bitsandbytes.txt

# %%
# !git clone https://github.com/yenyyo/R2-Research_Internship_2.git
# Change to the directory containing aux_extract_pdf
# %cd /content/R2-Research_Internship_2/01-code/
# Out:
# Cloning into 'R2-Research_Internship_2'...
# remote: Enumerating objects: 483, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 483 (delta 2), reused 9 (delta 2), pack-reused 470 (from 1)
# Receiving objects: 100% (483/483), 199.36 MiB | 23.46 MiB/s, done.
# Resolving deltas: 100% (170/170), done.
# /content/R2-Research_Internship_2/01-code

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import pdfplumber
import pandas as pd
import logger
import importlib

# %%
# !python 01-extract_pdf.py "../02-data/01-pdfs/" | tee logs/log_file.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG - add_results: ((46973, /b'Tj'),)
# DEBUG - nextobject: (46973, /b'Tj')
# DEBUG - exec: Tj [b'(']
# DEBUG - nexttoken: (46976, 0.333)
# DEBUG - add_results: ((46976, 0.333),)
# DEBUG - nextobject: (46976, 0.333)
# DEBUG - nexttoken: (46982, -0.1)
# DEBUG - add_results: ((46982, -0.1),)
# DEBUG - nextobject: (46982, -0.1)
# DEBUG - nexttoken: (46987, /b'Td')
# DEBUG - do_keyword: pos=46987, token=/b'Td', stack=[]
# DEBUG - add_results: ((46987, /b'Td'),)
# DEBUG - nextobject: (46987, /b'Td')
# DEBUG - exec: Td [0.333, -0.1]
# DEBUG - nexttoken: (46990, b'2')
# DEBUG - add_results: ((46990, b'2'),)
# DEBUG - nextobject: (46990, b'2')
# DEBUG - nexttoken: (46993, /b'Tj')
# DEBUG - do_keyword: pos=46993, token=/b'Tj', stack=[]
# DEBUG - add_results: ((46993, /b'Tj'),)
# DEBUG - nextobject: (46993, /b'Tj')
# DEBUG - exec: Tj [b'2']
# DEBUG - nexttoken: (46996, 0.556)
# DEBUG - add_results: ((46996, 0.556),)
# ...

# %%
# !python 02-image_to_text.py
# Out:
# 2025-01-29 17:04:09.696511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-29 17:04:09.716665: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-29 17:04:09.722637: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-29 17:04:11.037211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-01-29 17:04:12,103 - INFO - Starting image processing in folder: ../02-data/01-pdfs/00-testing
# 2025-01-29 17:04:12,103 - INFO - Processing folder: ../02-data/01-pdfs/00-testing
# ...
