# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/yenyyo/R2-Research_Internship_2.git

# !mv R2-Research_Internship_2/.git /content/
# !mv R2-Research_Internship_2/* /content/
# !rm -r R2-Research_Internship_2

# !rm -r sample_data
# !mkdir logs

# !pip install -r /content/00-documentation/requirements.txt >> logs/log_install.txt

# !tar -xvzf /content/02-data/00-testing/03-demo.tar.gz -C /content/02-data/00-testing/ >> logs/log_tar.txt
# Out:
# rm: cannot remove 'sample_data': No such file or directory
# mkdir: cannot create directory ‘logs’: File exists

# %%
# !mkdir -p ~/.ssh ##initialize the ssh functionallity in google colab
# !cp /content/drive/MyDrive/Colab\ Notebooks/id_rsa /content/
# !cp /content/id_rsa ~/.ssh/id_rsa >> logs/log_ssh.txt
# !chmod 600 ~/.ssh/id_rsa >> logs/log_ssh.txt
# !ssh-keyscan github.com >> ~/.ssh/known_hosts

# !echo "IdentityFile /content/id_rsa" >> ~/.ssh/config
# !chmod 600 ~/.ssh/config

# !ssh -T git@github.com ## just hello

# !git remote set-url origin git@github.com:yenyyo/R2-Research_Internship_2.git

## gitconfig is not preserved across sessions so need to remind thisguy who am i
# !git config --global user.name "yenyyo"
# !git config --global user.email "pdevicente@hotmail.com"
# Out:
# # github.com:22 SSH-2.0-48ecf9ce5
# # github.com:22 SSH-2.0-48ecf9ce5
# # github.com:22 SSH-2.0-48ecf9ce5
# # github.com:22 SSH-2.0-48ecf9ce5
# # github.com:22 SSH-2.0-48ecf9ce5
# Hi yenyyo/R2-Research_Internship_2! You've successfully authenticated, but GitHub does not provide shell access.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import pdfplumber
import pandas as pd
import logger
import importlib

# %%
# !python 01-extract_pdf.py "../02-data/00-testing/03-demo/batteries-non-rechargable-primary"  | tee ../../logs/log_file.txt
# Out:
# config.json: 100% 709/709 [00:00<00:00, 4.81MB/s]
# 2025-02-19 17:41:53.939466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739986913.961553    2916 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739986913.967584    2916 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors.index.json: 100% 27.8k/27.8k [00:00<00:00, 48.3MB/s]
# ...
# model-00001-of-00004.safetensors:   0% 0.00/4.88G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 10.5M/4.88G [00:00<02:01, 40.1MB/s]
# ...

# %%
# !python 02-image_to_text.py
# Out:
# 2025-02-18 11:58:25.203147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739879905.223658    6556 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739879905.229990    6556 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/content/R2-Research_Internship_2/01-code/02-image_to_text.py", line 179, in <module>
#     process_images(pdf_path, pre_filter)
#   File "/content/R2-Research_Internship_2/01-code/02-image_to_text.py", line 129, in process_images
# ...

# %%
# !git add 00-documentation/requirements.txt

# !git commit -m "requirements file added"

# !git push --set-upstream origin master
# Out:
# [master 7e0da7d] requirements file added
#  1 file changed, 5 insertions(+)
#  create mode 100644 00-documentation/requirements.txt
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 385 bytes | 385.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:yenyyo/R2-Research_Internship_2.git
#    5dbe933..7e0da7d  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
